# %% [markdown]
# # Proyek Analisis Data: E-Commerce Public dataset
# - Nama: WIFQO AROVA SYAMS
# - Email: wifqoarova17@gmail.com
# - Id Dicoding: WIFQO AROVA SYAMS

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana demografi customer dan seller dalam platform E-Commerce kita?
# - Seller mana yang paling banyak dan paling sedikit menghasilkan profit?
# - Kategory produk apa yang paling banyak dan paling sedikit terjual?
# - Bagaimana performa revenue seller dalam berapa bulan ini?
# - Apa penyebab dari bertambah dan berkurangnya jumlah pendapatan seller?

# %% [markdown]
# ## Menyiapkan semua library yang dibutuhkan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
# load all datasets from "E-Commerce Public Dataset" folder, then instanciate it as dataframe

customers_df = pd.read_csv("E-Commerce Public Dataset/customers_dataset.csv")
sellers_df = pd.read_csv("E-Commerce Public Dataset/sellers_dataset.csv")
products_df = pd.read_csv("E-Commerce Public Dataset/products_dataset.csv")
geolocation_df = pd.read_csv("E-Commerce Public Dataset/geolocation_dataset.csv")
product_category_name_translation_df = pd.read_csv("E-Commerce Public Dataset/product_category_name_translation.csv")
orders_df = pd.read_csv("E-Commerce Public Dataset/orders_dataset.csv")
order_reviews_df = pd.read_csv("E-Commerce Public Dataset/order_reviews_dataset.csv")
order_items_df = pd.read_csv("E-Commerce Public Dataset/order_items_dataset.csv")
order_payments_df = pd.read_csv("E-Commerce Public Dataset/order_payments_dataset.csv")

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### 1. Assessing Customer DataFrame
#
# data assessing result:
# - there are don't have a wrong datatype
# - there are no missing value
# - there are no duplicated value
# - there are no irregularities in statistic parameters (no column to be calculated)

# %%
# check for datatype
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
# check for missing value
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
# check for duplicated value
print("Duplicated Value:", customers_df.duplicated().sum())
# Out:
# Duplicated Value: 0

# %%
# check for statistic parameters
customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# #### 2. Assessing Sellers DataFrame
#
# data assessing result:
# - there are don't have a wrong datatype
# - there are no missing value
# - there are no duplicated value
# - there are no irregularities in statistic parameters (no column to be calculated)

# %%
# check for datatype
sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
# check for missing value
sellers_df.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
# check for duplicated value
print("Duplicated value:", sellers_df.duplicated().sum())
# Out:
# Duplicated value: 0

# %%
# check for parameter statistics
sellers_df.describe()
# Out:
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# #### 3. Assessing Product DataFrame
#
# data assessing result:
# - there are don't have a wrong datatype
# - there are have a lot missing value
# - there are no duplicated value
# - there are no irregularities in statistic parameters (no column to be calculated)

# %%
# check for datatype
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
# check for missing value
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
# check for duplicate value
print("Duplicated Value:", products_df.duplicated().sum())
# Out:
# Duplicated Value: 0

# %%
# check for statistic parameters
products_df.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# #### 4. Assessing Geolocations DataFrame
#
# data assessing result:
# - there are don't have a wrong datatype
# - there are no missing value
# - there are have 261831 duplicated value
# - there are no irregularities in statistic parameters (no column to be calculated)

# %%
# check for datatype
geolocation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
# check for missing value
geolocation_df.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
# check for duplicated data
geolocation_df.duplicated().sum()
# Out:
# 261831

# %%
# check for statistic parameters
geolocation_df.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %% [markdown]
# #### 5. Assessing Product Category Name Translation DataFrame
# data assessing result:
# - there are don't have a wrong datatype
# - there are no missing value
# - there are no duplicated value
# - there are no irregularities in statistic parameters (no column to be calculated)

# %%
# check for datatype
product_category_name_translation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
# check for missing value
product_category_name_translation_df.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
# check for duplicated value
product_category_name_translation_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### 6. Assessing Orders DataFrame
#
# data assessing result:
# - there are have a wrong datatype on timestamps columns
# - there are have a lot missing value
# - there are no duplicated value
# - there are no irregularities in statistic parameters (no column to be calculated)

# %%
# check for datatype
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
# check for missing value
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
# check for duplicated value
orders_df.duplicated().sum()
# Out:
# 0

# %%
# check for statistic parameters
orders_df.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# #### 7. Assessing Order Reviews DataFrame
#
# data assessing result:
# - there are have a wrong datatype in each datetime format
# - there are have a lot missing value
# - there are dont have duplicated data
# - there are no irregularities in the statistical parameters

# %%
# check for datatype
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
# check for missing value
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
# check for duplicated value
order_reviews_df.duplicated().sum()
# Out:
# 0

# %%
# check for statistics parameters
order_reviews_df.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# #### 8. Assessing Order Items DataFrame
#
# data assessing result:
# - there are have wrong datatype in date column
# - there are no missing values
# - there are no duplicated data
# - there are no irregularities in statistic parameters

# %%
# check for datatype
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
# check for missing value
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
# check duplicated data
order_items_df.duplicated().sum()
# Out:
# 0

# %%
# check for statictic parameters
order_items_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# #### 9. Assessing Order Payments DataFrame
#
# data assessing result:
# - there are don't have a wrong datatype
# - there are no missing value
# - there are no duplicated value
# - there are no irregularities in statistic parameters

# %%
# check for datatype
order_payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
# check missing values
order_payments_df.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
# check duplicated data
order_payments_df.duplicated().sum()
# Out:
# 0

# %%
# check statistic parameters
order_payments_df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Dataframe list to be cleaning

# %% [markdown]
# 1. Product DataFrame
#     - there are have a lot missing value
# 2. Geolocation DataFrame
#     - there are have 261831 duplicated value
# 3. Orders DataFrame
#     - there are have a wrong datatype on timestamps columns
#     - there are have a lot missing value
# 4. Order Reviews DataFrame
#     - there are have a wrong datatype in each datetime format
#     - there are have a lot missing value
# 5. Order Items DataFrame
#     - there are have wrong datatype in date column

# %% [markdown]
# #### 1. Cleaning Product DataFrame

# %%
# check the missing value
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
# fetch all data that have a missing value based on product_category_name
products_df[products_df.product_category_name.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
# fetch all data that have a missing value based on product_weight_g
products_df[products_df.product_weight_g.isna()]
# Out:
#                              product_id product_category_name  \
# 8578   09ff539a621711667c43eba6a3bd8466                 bebes
# 18851  5eb564652db742ff8f28759cd8d2652a                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 8578                  60.0                       865.0                 3.0
# 18851                  NaN                         NaN                 NaN
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 8578                NaN                NaN                NaN
# 18851               NaN                NaN                NaN
#
#        product_width_cm
# 8578                NaN
# 18851               NaN

# %%
"""
we can see that in one row data there are have a lot missing value in columns,
so better to delete all the data because we have experience lost that data
and the data is useless now because it's not provide the rellevant data
"""
products_df.dropna(axis=0, inplace=True)

# %% [markdown]
# #### 2. Cleaning Geolocation DataFrame

# %%
# delete all duplicated data
geolocation_df.drop_duplicates(inplace=True)

# %%
# check duplicated data
geolocation_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### 3. Cleaning Order DataFrame

# %%
# check before and after cleaned
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
# change date columns to datetime datatype
timestamp_columns = [
    "order_purchase_timestamp", 
    "order_approved_at", 
    "order_delivered_carrier_date", 
    "order_delivered_customer_date", 
    "order_estimated_delivery_date"
]

for column in timestamp_columns:
    orders_df[column] = pd.to_datetime(orders_df[column])

# %%
# check the missing value
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
# fetch data that order_approved_at have a missing value
orders_df[orders_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
# fetch data that order_delivered_carrier_date have a missing value
orders_df[orders_df.order_delivered_carrier_date.isna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 266    8e24261a7e58791d10cb1bf9da94df5c  64a254d30eed42cd0e6c36dddb88adf0
# 324    d3c8851a6651eeff2f73b0e011ac45d0  957f8e082185574de25992dc659ebbc0
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
# fetch data that order_delivered_customer_date have a missing value
orders_df[orders_df.order_delivered_customer_date.isna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 44     ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 154    6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
"""
we can conclude that all the data that have a missing value have a usefull data in the order status column,
so we can not delete the data, instead of make it with None format.
"""
# Out:
# '\nwe can conclude that all the data that have a missing value have a usefull data in the order status column,\nso we can not delete the data, instead of make it with None format.\n'

# %% [markdown]
# #### 4. Cleaning Order Reviews DataFrame

# %%
# check datatype
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
# change datetime column to datetime datatype format
datetime_columns = ["review_creation_date", "review_answer_timestamp"]

for column in datetime_columns:
    order_reviews_df[column] = pd.to_datetime(order_reviews_df[column])

# %%
# check missing value
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
"""
here we can conclude that the column that dont have a value is an optional(nullable) value that the customer
dont have an obligation for fill the column, so we can just make it like that
"""
# Out:
# '\nhere we can conclude that the column that dont have a value is an optional(nullable) value that the customer\ndont have an obligation for fill the column, so we can just make it like that\n'

# %% [markdown]
# #### 5. Cleaning Order Items DataFrame

# %%
# check datatype
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
# change to datetime
order_items_df["shipping_limit_date"] = pd.to_datetime(order_items_df["shipping_limit_date"])

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 1. Explore Customers_df Data

# %% [markdown]
# #### Explore Results:
# - We have total 99.441 customer
# - most of the customers are live in Sao Paulo City with total: 15.540 customers
# - most of the customers are live in SP State with total: 41.746 customers
# - total of city that customer live in is 4.119 cities
# - total of state that customer live in is 27 state

# %%
# describe customer_df
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
# make pivot table to count customer based on city
customers_df.groupby("customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %%
# make pivot tabel to count customer based on state
customers_df.groupby("customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %%
# count total city that customers live in
customers_df["customer_city"].nunique()
# Out:
# 4119

# %%
# count total state that customers live in
customers_df["customer_state"].nunique()
# Out:
# 27

# %% [markdown]
# ### 2. Explore Sellers_df Data

# %% [markdown]
# #### Explore Results:
# - we have total 3.095 seller
# - most of the seller are live in Sao Paulo with total: 694 sellers
# - most of the seller are live in SP state with total: 1.849 sellers
# - total of city that seller live in is 611 city
# - total of state that seller live in is 23 state

# %%
# describe seller
sellers_df.describe(include="all")
# Out:
#                                seller_id  seller_zip_code_prefix seller_city  \
# count                               3095             3095.000000        3095
# unique                              3095                     NaN         611
# top     3442f8959a84dea7ee197c632cb2df15                     NaN   sao paulo
# freq                                   1                     NaN         694
# mean                                 NaN            32291.059451         NaN
# std                                  NaN            32713.453830         NaN
# min                                  NaN             1001.000000         NaN
# 25%                                  NaN             7093.500000         NaN
# 50%                                  NaN            14940.000000         NaN
# 75%                                  NaN            64552.500000         NaN
# max                                  NaN            99730.000000         NaN
#
#        seller_state
# count          3095
# ...

# %%
# make pivot tabel to count customer based on city
sellers_df.groupby("seller_city").seller_id.nunique().sort_values(ascending=False)
# Out:
# seller_city
# sao paulo         694
# curitiba          127
# rio de janeiro     96
# belo horizonte     68
# ribeirao preto     52
#                  ...
# ivoti               1
# itirapina           1
# itau de minas       1
# itapui              1
# xaxim               1
# Name: seller_id, Length: 611, dtype: int64

# %%
# make pivot tabel to count customer based on state
sellers_df.groupby("seller_state").seller_id.nunique().sort_values(ascending=False)
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# CE      13
# PE       9
# PB       6
# MS       5
# RN       5
# MT       4
# RO       2
# SE       2
# AC       1
# PI       1
# AM       1
# MA       1
# PA       1
# Name: seller_id, dtype: int64

# %% [markdown]
# ### 3. Explore Products_df Data

# %% [markdown]
# #### Explore Results:
# - most of the product is from category bed_bath_table with 3.029 products, and the seccond is sports_leisure category with total 2.867 products.
# - average product have a 2 photos on marketplace, with min. 1 photo and max. 20 photos
# - average product have 771 description length, with min. 4 words and max. 3.992 words
# - average product weight is 2276.96 gram, with min. 0 gram and max. 40.425 gram

# %%
# describe product_df
products_df.describe(include="all")
# Out:
#                               product_id product_category_name  \
# count                              32340                 32340
# unique                             32340                    73
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama_mesa_banho
# freq                                   1                  3029
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32340.000000                32340.000000        32340.000000
# ...

# %%
"""
for more clear product category name, we will add product_category_name_english column with merge method.
merge product_df with product_category_name_translation_df
"""
products_english_df = pd.merge(
    left=products_df,
    right=product_category_name_translation_df,
    how="left",
    on="product_category_name"
)

# %%
# make pivot table based on product_category_name_english
products_english_df.groupby("product_category_name_english").product_id.count().sort_values(ascending=False)
# Out:
# product_category_name_english
# bed_bath_table               3029
# sports_leisure               2867
# furniture_decor              2657
# health_beauty                2444
# housewares                   2335
#                              ...
# tablets_printing_image          9
# home_comfort_2                  5
# fashion_childrens_clothes       5
# security_and_services           2
# cds_dvds_musicals               1
# Name: product_id, Length: 71, dtype: int64

# %% [markdown]
# ### 4. Explore Geolocation_df Data

# %% [markdown]
# #### Explore Results:
# - city that have a most zip code (area) is in sao paulo city with total 3171 area
# - state that have a most cities in in MG state with 1.426 cities, and then SP state with 1.048 cities
# - zip code (area) that have a most location is in zip code number 38400 with 746 locations, then zipcode number 35500 have 726 locations

# %%
# describe dataframe
geolocation_df.describe(include="all")
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# count                 738332.000000    738332.000000    738332.000000
# unique                          NaN              NaN              NaN
# top                             NaN              NaN              NaN
# freq                            NaN              NaN              NaN
# mean                   38316.086800       -20.998353       -46.461098
# std                    30632.496675         5.892315         4.393705
# min                     1001.000000       -36.605374      -101.466766
# 25%                    12600.000000       -23.603061       -48.867822
# 50%                    29144.000000       -22.873588       -46.647278
# 75%                    65950.000000       -19.923336       -43.836974
# max                    99990.000000        45.065933       121.105394
#
#        geolocation_city geolocation_state
# count            738332            738332
# ...

# %%
# make pivot tb. group by city to find how many zip_code per city
geolocation_df.groupby("geolocation_city").geolocation_zip_code_prefix.nunique().sort_values(ascending=False)
# Out:
# geolocation_city
# sao paulo               3171
# são paulo               3013
# brasilia                 496
# brasília                 406
# rio de janeiro           404
#                         ...
# guarei                     1
# guardinha                  1
# guarda-mor                 1
# guarda dos ferreiros       1
# óleo                       1
# Name: geolocation_zip_code_prefix, Length: 8011, dtype: int64

# %%
# make a pivot table group by state, how many city in one state
geolocation_df.groupby("geolocation_state").geolocation_city.nunique().sort_values(ascending=False)
# Out:
# geolocation_state
# MG    1426
# SP    1048
# RS     691
# BA     652
# PR     651
# SC     420
# GO     384
# MA     299
# PI     278
# PE     267
# CE     260
# PB     254
# RJ     245
# PA     219
# RN     214
# MT     213
# TO     173
# ES     160
# MS     133
# AL     130
# SE      96
# RO      83
# AM      74
# AC      34
# DF      28
# AP      17
# RR      14
# Name: geolocation_city, dtype: int64

# %%
# make a pivot table to see each zip code (area) have how many location
geolocation_df.groupby("geolocation_zip_code_prefix").agg({
    "geolocation_lat": "nunique",
    "geolocation_lng": "nunique"
}).sort_values(by="geolocation_lat", ascending=False)
# Out:
#                              geolocation_lat  geolocation_lng
# geolocation_zip_code_prefix
# 38400                                    746              745
# 35500                                    726              726
# 11680                                    726              726
# 11740                                    666              666
# 36400                                    627              627
# ...                                      ...              ...
# 11620                                      1                1
# 11625                                      1                1
# 35150                                      1                1
# 91509                                      1                1
# 25928                                      1                1
#
# [19015 rows x 2 columns]

# %% [markdown]
# ### 5. Explore Order_df Data

# %% [markdown]
# #### Explore Results:
#
# - we have total 99441 order
# - each customer just do 1 order
# - most of the order have done with delivered status in total 96.478 orders done
# - the order that have been canceled have a total 625 orders
# - the order that is still in process have a total 301 orders
# - the order that is still in shipment process is 1.107 orders
#
# - average seller performance to process approvable after customer purchased is with the same day which is fast response. and minimum with the same day, maximum 187 days after purchased.
# - average seller performance to process delivery to carrier after customer purchased is 2 days. and minimal with the same day, maximal 125 days after purchased
# - average customer waiting time from buy the product online until come to location is 12 days, and minimal with the same day, maximal 209 days after purchased.
# - average carrier delivery time to customer location is 8 days, and minimal with the same day, maximal 205 days
# - from total 96.478 order completed there are have 7826 orders that is Late and 88652 orders that is On Time

# %%
# describe order_df
orders_df.describe(include="all")
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# count         99441                          99441
# ...

# %%
# make pivot table based on order_status, to count how many each each order status
orders_df.groupby("order_status").order_id.nunique().sort_values(ascending=False)
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_id, dtype: int64

# %%
# make a pivot tabel grop by order_id to see how many order each customer
orders_df.groupby("order_id").customer_id.nunique().sort_values(ascending=False)
# Out:
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214    1
# ab291c01a71273689c1e6ea624b083dc    1
# ab344aaf7040ad7bcee8c7ae7db9e87e    1
# ab30f8d4ebb7d33d1dcf54d420ea42cd    1
# ab30f399d360ddf62897051d813f887d    1
#                                    ..
# 55539e6edbbf2276dc9e2eab8af0fa8d    1
# 55538582ef35a95e5ed4047c6bf04695    1
# 5553543e89ef381e4ff08f6b91b94690    1
# 55534471fcbe2dd1436234e7cfa4de5a    1
# fffe41c64501cc87c801fd61db3f6244    1
# Name: customer_id, Length: 99441, dtype: int64

# %%
# fetch order data that the order have been done
orders_done_df = orders_df[orders_df.order_status == "delivered"]

# %%
# seller performance to process approvable after customer purchased
# count days range between order purchased and approve
range_order_purchased_to_approved = orders_df["order_approved_at"] - orders_df["order_purchase_timestamp"]
range_order_purchased_to_approved = range_order_purchased_to_approved.apply(lambda x: x.total_seconds()//86400)
range_order_purchased_to_approved.sort_values()
# Out:
# 0        0.0
# 63040    0.0
# 63039    0.0
# 63038    0.0
# 63037    0.0
#         ...
# 97696    NaN
# 98415    NaN
# 98909    NaN
# 99283    NaN
# 99347    NaN
# Length: 99441, dtype: float64

# %%
# seller performance to process until delivery it to carrier after customer purchased
# count days range between order purchased and delivered to carrier
range_order_purchased_until_delivered_to_carrier = orders_df["order_delivered_carrier_date"] - orders_df["order_purchase_timestamp"]
range_order_purchased_until_delivered_to_carrier = range_order_purchased_until_delivered_to_carrier.apply(lambda x: x.total_seconds()//86400)
# if data dont have a datetime data, then throw 0
range_order_purchased_until_delivered_to_carrier = range_order_purchased_until_delivered_to_carrier.apply(lambda x: x if x > 0 else 0)

# %%
# time customer must wait from first do the purchase until come to the customer home
# count days range between order purchased and order delivered
range_order_purchased_to_delivered = orders_df["order_delivered_customer_date"] - orders_df["order_purchase_timestamp"]
range_order_purchased_to_delivered = range_order_purchased_to_delivered.apply(lambda x: x.total_seconds()//86400)

# %%
# carrier performance
# count days range between order delivered to carrier and order delivered to customer
range_order_delivered_to_carrier_and_delivered_to_customer = orders_df["order_delivered_customer_date"] - orders_df["order_estimated_delivery_date"]
range_order_delivered_to_carrier_and_delivered_to_customer = range_order_delivered_to_carrier_and_delivered_to_customer.apply(lambda x: x.total_seconds()//86400)
# if data dont have a datetime data, then throw 0
range_order_delivered_to_carrier_and_delivered_to_customer = range_order_delivered_to_carrier_and_delivered_to_customer.apply(lambda x: x if x > 0 else 0)

# %%
# make new order_performance data frame to track performance
d = {
    "order_id": orders_df["order_id"].tolist(),
    "order_purchased_to_approved_time": range_order_purchased_to_approved.tolist(),
    "order_purchased_until_delivered_to_carrier_time": range_order_purchased_until_delivered_to_carrier.tolist(),
    "order_purchased_to_delivered_time": range_order_purchased_to_delivered.tolist(),
    "order_from_carrier_to_delivered_time": range_order_delivered_to_carrier_and_delivered_to_customer.tolist()
}
order_performance_df = pd.DataFrame(data=d)

# %%
# order performance statistic parameters
order_performance_df.describe()
# Out:
#        order_purchased_to_approved_time  \
# count                      99281.000000
# mean                           0.269800
# std                            0.986202
# min                            0.000000
# 25%                            0.000000
# 50%                            0.000000
# 75%                            0.000000
# max                          187.000000
#
#        order_purchased_until_delivered_to_carrier_time  \
# count                                     99441.000000
# mean                                          2.697358
# std                                           3.566937
# min                                           0.000000
# 25%                                           1.000000
# 50%                                           2.000000
# 75%                                           4.000000
# max                                         125.000000
#
#        order_purchased_to_delivered_time  order_from_carrier_to_delivered_time
# ...

# %%
# order delivery accuracy time
range_order_delivered_customer_and_estimated_delivery_date = orders_df["order_estimated_delivery_date"] - orders_df["order_delivered_customer_date"]
range_order_delivered_customer_and_estimated_delivery_date = range_order_delivered_customer_and_estimated_delivery_date.apply(lambda x: x.total_seconds()//86400)

# %%
# make an order data that have been done
orders_done_df = pd.DataFrame(orders_df[orders_df.order_status == "delivered"])

# %%
"""
write "On Time" if delivered time is faster or same than estimated time,
write "Late" if delivered time is slower than estimated time,
wrte "Unavailable" if order is not delivered
"""

orders_done_df["order_delivery_accuracy_time"] = range_order_delivered_customer_and_estimated_delivery_date.apply(lambda x: "Late" if x < 0 else "On Time")

# %%
# get the total order that is ontime and late
orders_done_df.groupby("order_delivery_accuracy_time").order_id.nunique()
# Out:
# order_delivery_accuracy_time
# Late        7826
# On Time    88652
# Name: order_id, dtype: int64

# %% [markdown]
# ### 6. Explore Order_reviews_df Data

# %% [markdown]
# #### Explore Results:
# - average customer satisfaction is in rating score 4.09
# - most of customer give the 5 rating with 57.076 orders, and then 4 rating with 19.098 orders
# - there are a lot customers that give 1-3 rating, in total 22.701 orders. which is 11.393 customer is give the rating 1
# - average time seller to answer customer reviews is 2 days, with minimal time is at the same day, and the maximal time is 518 days after customer did the reviews

# %%
# describe order reviews
order_reviews_df.describe(include="all")
# Out:
#                                review_id                          order_id  \
# count                              99224                             99224
# unique                             98410                             98673
# top     7b606b0d57b078384f0b58eac1d41d78  c88b1d1b157a9999ce368f218a407141
# freq                                   3                                 3
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#         review_score review_comment_title review_comment_message  \
# ...

# %%
# make a pivot table to know how many feedback each review rating
order_reviews_df.groupby("review_score").order_id.nunique().sort_values(ascending=False)
# Out:
# review_score
# 5    57076
# 4    19098
# 1    11393
# 3     8160
# 2     3148
# Name: order_id, dtype: int64

# %%
# count range from review created until review answered by seller (day)
range_creation_date_and_answared_date = order_reviews_df["review_answer_timestamp"] - order_reviews_df["review_creation_date"]
range_creation_date_and_answared_date = range_creation_date_and_answared_date.apply(lambda x: x.total_seconds() // 86400)

# %%
# explore range time (day)
range_creation_date_and_answared_date.sort_values()
# Out:
# 0          0.0
# 46210      0.0
# 46212      0.0
# 46227      0.0
# 46229      0.0
#          ...
# 13920    446.0
# 8758     471.0
# 22059    508.0
# 66672    512.0
# 41620    518.0
# Length: 99224, dtype: float64

# %%
# find average (day)
range_creation_date_and_answared_date.mean()
# Out:
# 2.582248246392002

# %% [markdown]
# ### 7. Explore Order_items_df Data

# %% [markdown]
# #### Explore Results:
# - average order price is USD 120,65, with min USD 0,85 and max USD 6.735
# - average freight value is 19,99, with min 0 and max 409,68
# - from total 3.095 sellers, all have experience the order although at least just 1
# - seller that has a most handled order is in total 1854 orders, and smallest order is 1 order
# - seller that has most selled product have in total 399 products, and smallest amount of product  that have been selled is 1 product
# - seller that has a most revenue is have in total USD 229.472,63, and seller that has a smallest revenue is in total USD 3,50
# - maximum most revenue in 1 time order is USD 6.735
# - smallest revenue in 1 time order is USD 0,85
# - average revenue from all order have USD 4391.48

# %%
# describe df
order_items_df.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
# std                                  NaN       0.705124
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %%
# make a pivot table based on seller, how many order they handle and how many products they have been sell, and how many statistic params of their total revenue
order_items_pivot_tb = order_items_df.groupby("seller_id").agg({
    "order_id": "nunique",
    "product_id": "nunique",
    "price": ["sum", "max", "min"]
}).rename(columns={
    "order_id": "order_count",
    "product_id": "product_count",
})

# %%
# sort values by price total
order_items_pivot_tb.sort_values(by=("price", "sum"), ascending=False)
# Out:
#                                  order_count product_count      price  \
#                                      nunique       nunique        sum
# seller_id
# 4869f7a5dfa277a7dca6462dcf3b52b2        1132            95  229472.63
# 53243585a1d6dc2643021fd1853d8905         358            23  222776.05
# 4a3ca9315b744ce9f8e9374361493884        1806           399  200472.92
# fa1c13f2614d7b5c4749cbc52fecda94         585           289  194042.03
# 7c67e1448b00f6e969d365cea6b010ab         982           198  187923.89
# ...                                      ...           ...        ...
# 34aefe746cd81b7f3b23253ea28bef39           1             1       8.00
# 702835e4b785b67a084280efca355756           1             1       7.60
# 1fa2d3def6adfa70e58c276bb64fe5bb           1             1       6.90
# 77128dec4bec4878c37ab7d6169d6f26           1             1       6.50
# cf6f6bc4df3999b9c6440f124fb2f687           1             1       3.50
#
#
# ...

# %%
# find most revenue in 1 time order
order_items_pivot_tb.sort_values(by=("price", "max"), ascending=False)
# Out:
#                                  order_count product_count    price          \
#                                      nunique       nunique      sum     max
# seller_id
# e3b4998c7a498169dc7bce44e6bb6277           3             3   6897.9  6735.0
# 80ceebb4ee9b31afb6c6a916a574a1e2           1             1   6729.0  6729.0
# ee27a8f15b1dded4d213a468ba4eb391           1             1   6499.0  6499.0
# 59417c56835dd8e2e72f91f809cd4092          18             9  36459.0  4799.0
# c72de06d72748d1a0dfb2125be43ba63          21             8  17522.0  4590.0
# ...                                      ...           ...      ...     ...
# 1fa2d3def6adfa70e58c276bb64fe5bb           1             1      6.9     6.9
# 77128dec4bec4878c37ab7d6169d6f26           1             1      6.5     6.5
# 6c9875b2f94ba781186f0c1aed8d1687           2             2     25.0     6.5
# 3d62f86afa7c73be2628a3be1423f5a0           2             1     12.0     6.0
# ...

# %%
# find smallest revenue in 1 order
order_items_pivot_tb.sort_values(by=("price", "min"), ascending=True)
# Out:
#                                  order_count product_count     price           \
#                                      nunique       nunique       sum      max
# seller_id
# 96804ea39d96eb908e7c3afdb671bb9e          38             5   3610.70   149.95
# 2709af9587499e95e803a6498a5a56e9          26            15   1279.56   154.00
# 2d2322d842118867781fc737e96d59a1           8             5    176.40    24.50
# 0e44d110fa6a54e121cb2c095a77762f           6             5    223.32   136.68
# 48efc9d94a9834137efd9ea76b065a38          33            17    345.60    14.90
# ...                                      ...           ...       ...      ...
# e2a1ac9bf33e5549a2a4f834e70df2f8           5             1  14999.45  2999.89
# a00824eb9093d40e589b940ec45c4eb0           3             1   9399.97  3399.99
# 585175ec331ea177fa47199e39a6170a           1             1   3549.00  3549.00
# ee27a8f15b1dded4d213a468ba4eb391           1             1   6499.00  6499.00
# ...

# %%
# count how many seller that have been done the order
order_items_df["seller_id"].nunique()
# Out:
# 3095

# %%
# find the average from all order done
order_items_pivot_tb.price.mean()
# Out:
# sum    4391.484233
# max     335.419590
# min     110.384701
# dtype: float64

# %% [markdown]
# ### 8. Explore Order_payments_df Data

# %% [markdown]
# #### Explore Results:
# - average payment sequential is 1 time, with min value is have 1 and max value is 29
# - average payment installments is 2,85 month, with minimal no installment, and maximal 24 month
# - average payment value is USD 154,1, and with min USD 0 and max USD 13.664,08
# - credit card handle the most payment value that is in total USD 12.542.084,19
# - credit card have handled most of the payment installment with maximal 24 month
# - credit card too handled the most of the order for being transaction method with useness in 76.505 order

# %%
# describe order payment DF
order_payments_df.describe(include="all")
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %%
# make pivot tabel based on payment type
order_payments_df.groupby("payment_type").agg({
    "order_id": "nunique",
    "payment_sequential": "mean",
    "payment_installments": ["mean", "max", "min"],
    "payment_value": "sum"
})
# Out:
#              order_id payment_sequential payment_installments          \
#               nunique               mean                 mean max min
# payment_type
# boleto          19784           1.000051             1.000000   1   1
# credit_card     76505           1.004167             3.507155  24   0
# debit_card       1528           1.034663             1.000000   1   1
# not_defined         3           1.000000             1.000000   1   1
# voucher          3866           2.602424             1.000000   1   1
#
#              payment_value
#                        sum
# payment_type
# boleto          2869361.27
# credit_card    12542084.19
# debit_card       217989.79
# not_defined           0.00
# voucher          379436.87

# %% [markdown]
# ### Explore and Merge Orders &  Customer Data

# %% [markdown]
# #### Explore Results:
# - most of the order is done from Sao Paulo city with total 15.540 orders
# - most of the order is done in SP state with total 41.746 orders
# - SP state have handled the most order delivered done with total 40.501 order delivered
# - also SP state is experience the most canceled order with total 327 order canceled

# %%
# merge customer_df to order_df
orders_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_customers_df.head(10)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 5  a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 6  136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 7  6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# 8  76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 9  e69bfb5eb88e0ed6a785585b27e16dbf  31ad1d1b63eb9962463f764d4e6e0c9d
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# ...

# %%
# group by customer city
orders_customers_df.groupby("customer_city").order_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: order_id, Length: 4119, dtype: int64

# %%
# group by customer state
orders_customers_df.groupby("customer_state").order_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: order_id, dtype: int64

# %%
# make a pivot table to see whick state handled the most delivered order done, and canceled order
orders_customers_df.groupby(by=["customer_state", "order_status"]).order_id.nunique().sort_values(ascending=False)
# Out:
# customer_state  order_status
# SP              delivered       40501
# RJ              delivered       12350
# MG              delivered       11354
# RS              delivered        5345
# PR              delivered        4923
#                                 ...
# PI              unavailable         1
# PR              created             1
# RJ              created             1
# RR              canceled            1
# TO              unavailable         1
# Name: order_id, Length: 149, dtype: int64

# %% [markdown]
# ### Explore and Merge Orders, Customers & Payments Data

# %%
# merge order_payments_df to orders_customers_df
orders_customers_payments_df = pd.merge(
    left=orders_customers_df,
    right=order_payments_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
orders_customers_payments_df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 103882  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 103883  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 103884  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 103885  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 103886  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp   order_approved_at  \
# ...

# %% [markdown]
# ### Explore and Merge Orders, Customers, Payments & Reviews Data

# %%
# merge order_reviews_df to orders_customers_payments_df
orders_customers_payments_reviews_df = pd.merge(
    left=orders_customers_payments_df,
    right=order_reviews_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
orders_customers_payments_reviews_df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 104473  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 104474  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 104475  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 104476  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 104477  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp   order_approved_at  \
# ...

# %% [markdown]
# ### Explore and Merge Order Items & Products Data

# %% [markdown]
# #### Explore Results:
# - all order is have the average product weight in total 2.099,98 g
# - order with the minimum weight is 0 g, and the maximum weight is 40.425 g
# - bed bath table have a most selled product category with the total 9.417 order
# - security and services product category have a smallest selled with the total 2 order

# %%
order_items_products_df = pd.merge(
    left=order_items_df,
    right=products_english_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
order_items_products_df.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
# std                                  NaN       0.705124
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %%
# find the product category that have most selled in orders
order_items_products_df.groupby("product_category_name_english").order_id.nunique().sort_values(ascending=False)
# Out:
# product_category_name_english
# bed_bath_table               9417
# health_beauty                8836
# sports_leisure               7720
# computers_accessories        6689
# furniture_decor              6449
#                              ...
# arts_and_craftmanship          23
# la_cuisine                     13
# cds_dvds_musicals              12
# fashion_childrens_clothes       8
# security_and_services           2
# Name: order_id, Length: 71, dtype: int64

# %% [markdown]
# ### Explore and Merge Order Items, Products, & sellers Data

# %%
# merge sellers_df to order_items_products_df
order_items_products_sellers_df = pd.merge(
    left=order_items_products_df,
    right=sellers_df,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)
order_items_products_sellers_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %% [markdown]
# ### Merge All Data Frame

# %%
# merge all data frame 
all_df = pd.merge(
    left=orders_customers_payments_reviews_df,
    right=order_items_products_sellers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 119138  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 119139  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 119140  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 119141  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 119142  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp   order_approved_at  \
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### 1. Bagaimana demografi customer dan seller dalam platform E-Commerce kita?:

# %%
# demografi customer by state
customer_bystate_df = all_df.groupby("customer_state").customer_id.nunique().reset_index()
customer_bystate_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)

# make visualization
plt.figure(figsize=(10, 5))
colors = ["#006e87", "#00c6f2", "#00c6f2", "#00c6f2", "#00c6f2"]

sns.barplot(y="customer_state", x="customer_count", data=customer_bystate_df.sort_values(by="customer_count" ,ascending=False).head(5), palette=colors)
plt.title("Number Of Customer By State", loc="center", fontsize=15)
plt.xlabel(None)
plt.ylabel(None)
plt.tick_params(axis="y", labelsize=12)
plt.show()
# Out:
# /tmp/ipykernel_12573/286619243.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="customer_state", x="customer_count", data=customer_bystate_df.sort_values(by="customer_count" ,ascending=False).head(5), palette=colors)

# %%
# demografi seller by state
seller_bystate_df = all_df.groupby("seller_state").seller_id.nunique().reset_index()
seller_bystate_df.rename(columns={
    "seller_id": "seller_count"
}, inplace=True)

# make visualization
plt.figure(figsize=(10, 5))
colors = ["#006e87", "#00c6f2", "#00c6f2", "#00c6f2", "#00c6f2"]

sns.barplot(y="seller_state", x="seller_count", data=seller_bystate_df.sort_values(by="seller_count" ,ascending=False).head(5), palette=colors)
plt.title("Number Of Seller By State", loc="center", fontsize=15)
plt.xlabel(None)
plt.ylabel(None)
plt.tick_params(axis="y", labelsize=12)
plt.show()
# Out:
# /tmp/ipykernel_12573/890472073.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="seller_state", x="seller_count", data=seller_bystate_df.sort_values(by="seller_count" ,ascending=False).head(5), palette=colors)

# %% [markdown]
# ### 2. Seller mana yang paling banyak dan paling sedikit menghasilkan profit?:

# %%
# make new df based on seller id to view total revenue
seller_revenues_df = all_df.groupby("seller_id").price.sum().reset_index()
seller_revenues_df.rename(columns={
    "price": "revenue"
}, inplace=True)

# shortened the seller name to 3 unique id
seller_revenues_df["seller_id"] = seller_revenues_df["seller_id"].apply(lambda x: x[0:3])

# make visualization
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(26,6))
colors = ["#006e87", "#00c6f2", "#00c6f2", "#00c6f2", "#00c6f2"]

# highest profited seller
sns.barplot(y="revenue", x="seller_id", data=seller_revenues_df.sort_values(by="revenue", ascending=False).head(5), palette=colors, hue=colors, legend=False, ax=ax[0])
ax[0].set_title("Sellers With The Highest Profits", loc="center", fontsize=15)
ax[0].set_xlabel("Seller id")
ax[0].set_ylabel(None)
ax[0].tick_params(axis="x", labelsize=12)

# lowest profited seller
sns.barplot(y="revenue", x="seller_id", data=seller_revenues_df.sort_values(by="revenue", ascending=True).head(5), palette=colors, hue=colors, legend=False, ax=ax[1])
ax[1].set_title("Sellers With The Lowest Profits", loc="center", fontsize=15)
ax[1].set_xlabel("Seller id")
ax[1].set_ylabel(None)
ax[1].tick_params(axis="x", labelsize=12)

plt.suptitle("Sellers wuth Highest and Lowest Profits (USD)", fontsize=20)
plt.show()
# Out:
# /tmp/ipykernel_12573/32100713.py:15: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.barplot(y="revenue", x="seller_id", data=seller_revenues_df.sort_values(by="revenue", ascending=False).head(5), palette=colors, hue=colors, legend=False, ax=ax[0])
# /tmp/ipykernel_12573/32100713.py:22: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.barplot(y="revenue", x="seller_id", data=seller_revenues_df.sort_values(by="revenue", ascending=True).head(5), palette=colors, hue=colors, legend=False, ax=ax[1])

# %% [markdown]
# ### 3. Kategory produk apa yang paling banyak dan paling sedikit terjual?:

# %%
# make new df based on product category
product_categories_df = all_df.groupby("product_category_name_english").order_id.nunique().reset_index()
product_categories_df.rename(columns={
    "product_category_name_english": "product_category_name",
    "order_id": "quantity"
}, inplace=True)

# make visualization
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(26, 6))
colors = ["#006e87", "#00c6f2", "#00c6f2", "#00c6f2", "#00c6f2"]

# best performing product category
sns.barplot(x="quantity", y="product_category_name", data=product_categories_df.sort_values(by="quantity", ascending=False).head(5), palette=colors, ax=ax[0])
ax[0].set_xlabel(None)
ax[0].set_ylabel(None)
ax[0].set_title("Best Performing Product Category", loc="center", fontsize=15)
ax[0].tick_params(axis="y", labelsize=12)

# worst performing product category
sns.barplot(x="quantity", y="product_category_name", data=product_categories_df.sort_values(by="quantity", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_xlabel(None)
ax[1].set_ylabel(None)
ax[1].set_title("Worst Performing Product Category", loc="center", fontsize=15)
ax[1].tick_params(axis="y", labelsize=12)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()

plt.suptitle("Best and Worst Performing Product Category By Number Of Sales", fontsize=20)
plt.show()
# Out:
# /tmp/ipykernel_12573/95817280.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="quantity", y="product_category_name", data=product_categories_df.sort_values(by="quantity", ascending=False).head(5), palette=colors, ax=ax[0])
# /tmp/ipykernel_12573/95817280.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="quantity", y="product_category_name", data=product_categories_df.sort_values(by="quantity", ascending=True).head(5), palette=colors, ax=ax[1])

# %% [markdown]
# ### 4. Bagaimana performa revenue seller dalam berapa bulan ini?:

# %%
# make new df based on month
monthly_order_df = all_df.resample(rule="M", on="order_purchase_timestamp").agg({
    "order_id": "nunique",
    "price": "sum",
    "review_score": "mean"
}).reset_index()
monthly_order_df.rename(columns={
    "order_id": "order_count",
    "price": "seller_revenue"
}, inplace=True)
monthly_order_df
# Out:
#    order_purchase_timestamp  order_count  seller_revenue  review_score
# 0                2016-09-30            4          267.36      1.000000
# 1                2016-10-31          324        51068.92      3.524051
# 2                2016-11-30            0            0.00           NaN
# 3                2016-12-31            1           10.90      5.000000
# 4                2017-01-31          800       129895.32      4.083089
# 5                2017-02-28         1780       262013.86      3.999051
# 6                2017-03-31         2682       398117.44      4.037636
# 7                2017-04-30         2404       392595.36      3.967426
# 8                2017-05-31         3700       549226.84      4.114536
# 9                2017-06-30         3245       456867.47      4.117447
# 10               2017-07-31         4026       536906.96      4.088613
# 11               2017-08-31         4331       606026.98      4.209356
# ...

# %%
# make visualization numbe of order per month
plt.figure(figsize=(10, 5))
plt.plot(monthly_order_df["order_purchase_timestamp"], monthly_order_df["order_count"], marker="o", linewidth=2, color="#006e87")
plt.title("Number of Order Per Month", loc="center", fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
# make visualization total all seller revenue per month
plt.figure(figsize=(10, 5))
plt.plot(monthly_order_df["order_purchase_timestamp"], monthly_order_df["seller_revenue"], marker="o", linewidth=2, color="#006e87")
plt.title("Total All Seller Revenue Per Month (USD)", loc="center", fontsize=20)
plt.xticks(fontsize=10)
plt.ylabel("Million")
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ### 5. Apa penyebab dari bertambah dan berkurangnya jumlah pendapatan seller?

# %%
# Cluster analysis per Seller
cluster_byseller_df = all_df.groupby("seller_id").agg({
    "order_id": "nunique",
    "price": "sum",
    "review_score": "mean"
}).reset_index()
cluster_byseller_df.rename(columns={
    "order_id": "order_count",
    "price": "seller_revenue",
}, inplace=True)
cluster_byseller_df

fig, ax = plt.subplots(ncols=3, nrows=1, figsize=(30, 6))

# watch the relationship between revenue and order
sns.scatterplot(data=cluster_byseller_df, y="order_count", x="seller_revenue", ax=ax[0])
ax[0].set_xlabel("Seller Revenue")
ax[0].set_ylabel("Order Count")
ax[0].set_title("Relationship between Order & Revenue", fontsize=18)

# watch relation between order and review score
sns.scatterplot(data=cluster_byseller_df, y="order_count", x="review_score", ax=ax[1])
ax[1].set_xlabel("Review Score")
ax[1].set_ylabel("Order Count")
ax[1].set_title("Relationship between Review & Order", fontsize=18)

# watch relation between seller_revenue and review score
sns.scatterplot(data=cluster_byseller_df, y="seller_revenue", x="review_score", ax=ax[2])
ax[2].set_xlabel("Review Score")
ax[2].set_ylabel("Seller Revenue")
ax[2].set_title("Relationship between Review & Revenue", fontsize=18)

plt.suptitle("Revenue Cluster Analysis Per Seller", fontsize=20)
plt.show()

# %%
# cluster analysis per month
fig, ax = plt.subplots(ncols=3, nrows=1, figsize=(30, 6))

# watch the relationship between revenue and order
sns.scatterplot(data=monthly_order_df, y="order_count", x="seller_revenue", ax=ax[0])
ax[0].set_xlabel("Seller Revenue")
ax[0].set_ylabel("Order Count")
ax[0].set_title("Relationship between Order & Revenue", fontsize=18)

# watch relation between order and review score
sns.scatterplot(data=monthly_order_df, y="order_count", x="review_score", ax=ax[1])
ax[1].set_xlabel("Review Score")
ax[1].set_ylabel("Order Count")
ax[1].set_title("Relationship between Review & Order", fontsize=18)

# watch relation between seller_revenue and review score
sns.scatterplot(data=monthly_order_df, y="seller_revenue", x="review_score", ax=ax[2])
ax[2].set_xlabel("Review Score")
ax[2].set_ylabel("Seller Revenue")
ax[2].set_title("Relationship between Review & Revenue", fontsize=18)

plt.suptitle("Revenue Cluster Analysis Per Month", fontsize=20)
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### Conclution pertanyaan 1
# - Demografi Customer mayoritas bertempat tinggal di negara bagian SP (Sao Paulo)
# - Demografi Seller mayoritas bertempat tinggal di negara bagian SP (Sao Paulo)
# ### Conclution pertanyaan 2
# - Berdasarkan data visual diatas seller yang paling banyak menghasilkan profit adalah seller dengan id 3 digit pertama 532
# - dan seller yang menghasilkan profit terkecil adalah seller dengan id 3 digit pertama cf6
# ### Conclution pertanyaan 3
# - Bed bath table merupakan kategori produk dengan penjualan terbanyak
# - sedangkan kategori produk dengan jomlah penjualan terkecil adalah security and service
# ### Conclution pertanyaan 4
# - Dapat dilihat sejak bulan oktober 2016 sampai bulan april 2018 tren penjualan terus meningkat
# - setelah bulan april 2018 hingga oktober 2018 tren berbalik kearah turun, dengan tren turun terparah berada sejak bulan agustus 2018 hingga oktober 2018
# ### Conclution pertanyaan 5
# - setelah dijalankan beberapa pengujian dengan mencari hubungan antara revenue, order count, dan rating. dapat disimpulkan bahwa penyebab dari naik dan turunnya pendapatan berasal dari jumlah order
# - dan penyebab dari kenaikan dan penurunan order tidak dipengaruhi oleh rating dari review order
