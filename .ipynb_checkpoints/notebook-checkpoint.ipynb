# %% [markdown]
# # Proyek Analisis Data: Nama dataset
# - Nama:
# - Email:
# - Id Dicoding:

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - pertanyaan 1
# - pertanyaan 2

# %% [markdown]
# ## Menyaipkan semua library yang dibuthkan

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
# Out:
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: bundlerextension console dejavu events execute fileid
# kernel kernelspec lab labextension labhub migrate nbclassic nbconvert
# nbextension notebook qtconsole run server serverextension troubleshoot trust
#
# Jupyter command `jupyter-contrib` not found.

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
# !pip install jupyter_contrib_nbextensions
# Out:
# Collecting jupyter_contrib_nbextensions
#   Using cached jupyter_contrib_nbextensions-0.7.0.tar.gz (23.5 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipython_genutils in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Collecting jupyter_contrib_core>=0.3.3
#   Using cached jupyter_contrib_core-0.4.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jupyter_core in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter_contrib_nbextensions) (5.4.0)
# Requirement already satisfied: jupyter_highlight_selected_word>=0.1.1 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Collecting jupyter_nbextensions_configurator>=0.4.0
#   Using cached jupyter_nbextensions_configurator-0.6.3-py2.py3-none-any.whl (466 kB)
# Requirement already satisfied: lxml in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter_contrib_nbextensions) (4.9.3)
# Requirement already satisfied: nbconvert>=6.0 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter_contrib_nbextensions) (7.9.2)
# Requirement already satisfied: notebook>=6.0 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter_contrib_nbextensions) (7.0.6)
# Requirement already satisfied: tornado in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter_contrib_nbextensions) (6.3.3)
# Requirement already satisfied: traitlets>=4.1 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter_contrib_nbextensions) (5.12.0)
# Requirement already satisfied: setuptools in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter_contrib_core>=0.3.3->jupyter_contrib_nbextensions) (66.1.1)
# Requirement already satisfied: pyyaml in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (6.0.1)
# Requirement already satisfied: beautifulsoup4 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (6.1.0)
# Requirement already satisfied: defusedxml in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: markupsafe>=2.0 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.9.2)
# Requirement already satisfied: packaging in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (23.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.16.1)
# Requirement already satisfied: tinycss2 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.2.1)
# Requirement already satisfied: platformdirs>=2.5 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter_core->jupyter_contrib_nbextensions) (3.11.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (2.9.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (2.25.0)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (4.0.7)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.2.3)
# Requirement already satisfied: six>=1.9.0 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.16.0)
# Requirement already satisfied: webencodings in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: anyio>=3.1.0 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (4.0.0)
# Requirement already satisfied: argon2-cffi in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (8.5.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (0.4.4)
# Requirement already satisfied: overrides in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (7.4.0)
# Requirement already satisfied: prometheus-client in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (0.17.1)
# Requirement already satisfied: pyzmq>=24 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (25.1.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (0.17.1)
# Requirement already satisfied: websocket-client in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (1.6.4)
# Requirement already satisfied: async-lru>=1.0.0 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.4)
# Requirement already satisfied: ipykernel in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (6.26.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.0)
# Requirement already satisfied: babel>=2.10 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.13.1)
# Requirement already satisfied: json5>=0.9.0 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.9.14)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (4.19.1)
# Requirement already satisfied: requests>=2.31 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.31.0)
# Requirement already satisfied: fastjsonschema in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.18.1)
# Requirement already satisfied: soupsieve>1.2 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.5)
# Requirement already satisfied: idna>=2.8 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (2.8.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (3.3.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2023.7.22)
# Requirement already satisfied: ptyprocess in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (21.2.0)
# Requirement already satisfied: comm>=0.1.1 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (8.16.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (1.5.8)
# Requirement already satisfied: psutil in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (5.9.6)
# Requirement already satisfied: backcall in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: decorator in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.19.1)
# Requirement already satisfied: pickleshare in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.39)
# Requirement already satisfied: stack-data in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (4.8.0)
# Requirement already satisfied: fqdn in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (1.5.1)
# Requirement already satisfied: isoduration in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.4)
# Requirement already satisfied: uri-template in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (1.16.0)
# Requirement already satisfied: pycparser in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=6.0->jupyter_contrib_nbextensions) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: wcwidth in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.8)
# Requirement already satisfied: arrow>=0.15.0 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: executing>=1.2.0 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (2.4.1)
# Requirement already satisfied: pure-eval in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.8.19.14)
# Building wheels for collected packages: jupyter_contrib_nbextensions, jupyter_contrib_core
#   Building wheel for jupyter_contrib_nbextensions (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [2086 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib
#       creating build/lib/jupyter_contrib_nbextensions
#       copying src/jupyter_contrib_nbextensions/install.py -> build/lib/jupyter_contrib_nbextensions
#       copying src/jupyter_contrib_nbextensions/__init__.py -> build/lib/jupyter_contrib_nbextensions
#       copying src/jupyter_contrib_nbextensions/application.py -> build/lib/jupyter_contrib_nbextensions
#       copying src/jupyter_contrib_nbextensions/migrate.py -> build/lib/jupyter_contrib_nbextensions
#       creating build/lib/jupyter_contrib_nbextensions/nbconvert_support
#       copying src/jupyter_contrib_nbextensions/nbconvert_support/js_highlight.py -> build/lib/jupyter_contrib_nbextensions/nbconvert_support
#       copying src/jupyter_contrib_nbextensions/nbconvert_support/pre_embedimages.py -> build/lib/jupyter_contrib_nbextensions/nbconvert_support
#       copying src/jupyter_contrib_nbextensions/nbconvert_support/__init__.py -> build/lib/jupyter_contrib_nbextensions/nbconvert_support
#       copying src/jupyter_contrib_nbextensions/nbconvert_support/toc2.py -> build/lib/jupyter_contrib_nbextensions/nbconvert_support
#       copying src/jupyter_contrib_nbextensions/nbconvert_support/execute_time.py -> build/lib/jupyter_contrib_nbextensions/nbconvert_support
#       copying src/jupyter_contrib_nbextensions/nbconvert_support/pp_highlighter.py -> build/lib/jupyter_contrib_nbextensions/nbconvert_support
#       copying src/jupyter_contrib_nbextensions/nbconvert_support/pre_codefolding.py -> build/lib/jupyter_contrib_nbextensions/nbconvert_support
#       copying src/jupyter_contrib_nbextensions/nbconvert_support/collapsible_headings.py -> build/lib/jupyter_contrib_nbextensions/nbconvert_support
#       copying src/jupyter_contrib_nbextensions/nbconvert_support/exporter_inliner.py -> build/lib/jupyter_contrib_nbextensions/nbconvert_support
#       copying src/jupyter_contrib_nbextensions/nbconvert_support/pre_pymarkdown.py -> build/lib/jupyter_contrib_nbextensions/nbconvert_support
#       copying src/jupyter_contrib_nbextensions/nbconvert_support/nbTranslate.py -> build/lib/jupyter_contrib_nbextensions/nbconvert_support
#       copying src/jupyter_contrib_nbextensions/nbconvert_support/embedhtml.py -> build/lib/jupyter_contrib_nbextensions/nbconvert_support
#       copying src/jupyter_contrib_nbextensions/nbconvert_support/pre_svg2pdf.py -> build/lib/jupyter_contrib_nbextensions/nbconvert_support
#       creating build/lib/jupyter_contrib_nbextensions/config_scripts
#       copying src/jupyter_contrib_nbextensions/config_scripts/__init__.py -> build/lib/jupyter_contrib_nbextensions/config_scripts
#       copying src/jupyter_contrib_nbextensions/config_scripts/highlight_html_cfg.py -> build/lib/jupyter_contrib_nbextensions/config_scripts
#       copying src/jupyter_contrib_nbextensions/config_scripts/highlight_latex_cfg.py -> build/lib/jupyter_contrib_nbextensions/config_scripts
#       running egg_info
#       writing src/jupyter_contrib_nbextensions.egg-info/PKG-INFO
#       writing dependency_links to src/jupyter_contrib_nbextensions.egg-info/dependency_links.txt
#       writing entry points to src/jupyter_contrib_nbextensions.egg-info/entry_points.txt
#       writing requirements to src/jupyter_contrib_nbextensions.egg-info/requires.txt
#       writing top-level names to src/jupyter_contrib_nbextensions.egg-info/top_level.txt
#       reading manifest file 'src/jupyter_contrib_nbextensions.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no previously-included files found matching '.travis.yml'
#       warning: no previously-included files found matching 'appveyor.yml'
#       warning: no previously-included files found matching 'codecov.yml'
#       warning: no previously-included files found matching 'readthedocs.yml'
#       no previously-included directories found matching 'src/jupyter_contrib_nbextensions/nbextensions/spellchecker/typo/dictionaries'
#       no previously-included directories found matching 'conda.recipe'
#       warning: no previously-included files matching '*~' found anywhere in distribution
#       warning: no previously-included files matching '__pycache__' found anywhere in distribution
#       warning: no previously-included files matching '*.py[cod]' found anywhere in distribution
#       warning: no previously-included files matching '.git' found anywhere in distribution
#       warning: no previously-included files matching '.ipynb_checkpoints' found anywhere in distribution
#       warning: no previously-included files matching '.DS_Store' found anywhere in distribution
#       writing manifest file 'src/jupyter_contrib_nbextensions.egg-info/SOURCES.txt'
#       /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'jupyter_contrib_nbextensions.nbextensions.addbefore' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.addbefore' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'jupyter_contrib_nbextensions.nbextensions.addbefore' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'jupyter_contrib_nbextensions.nbextensions.addbefore' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'jupyter_contrib_nbextensions.nbextensions.autosavetime' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.autosavetime' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'jupyter_contrib_nbextensions.nbextensions.autosavetime' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'jupyter_contrib_nbextensions.nbextensions.autosavetime' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'jupyter_contrib_nbextensions.nbextensions.autoscroll' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.autoscroll' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'jupyter_contrib_nbextensions.nbextensions.autoscroll' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'jupyter_contrib_nbextensions.nbextensions.autoscroll' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'jupyter_contrib_nbextensions.nbextensions.cell_filter' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.cell_filter' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'jupyter_contrib_nbextensions.nbextensions.cell_filter' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'jupyter_contrib_nbextensions.nbextensions.cell_filter' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'jupyter_contrib_nbextensions.nbextensions.code_font_size' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.code_font_size' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'jupyter_contrib_nbextensions.nbextensions.code_font_size' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'jupyter_contrib_nbextensions.nbextensions.code_font_size' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'jupyter_contrib_nbextensions.nbextensions.code_prettify' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.code_prettify' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'jupyter_contrib_nbextensions.nbextensions.code_prettify' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'jupyter_contrib_nbextensions.nbextensions.code_prettify' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'jupyter_contrib_nbextensions.nbextensions.codefolding' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.codefolding' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'jupyter_contrib_nbextensions.nbextensions.codefolding' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'jupyter_contrib_nbextensions.nbextensions.codefolding' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'jupyter_contrib_nbextensions.nbextensions.codemirror_mode_extensions' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.codemirror_mode_extensions' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'jupyter_contrib_nbextensions.nbextensions.codemirror_mode_extensions' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'jupyter_contrib_nbextensions.nbextensions.codemirror_mode_extensions' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'jupyter_contrib_nbextensions.nbextensions.collapsible_headings' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.collapsible_headings' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'jupyter_contrib_nbextensions.nbextensions.collapsible_headings' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'jupyter_contrib_nbextensions.nbextensions.collapsible_headings' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'jupyter_contrib_nbextensions.nbextensions' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'jupyter_contrib_nbextensions.nbextensions' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'jupyter_contrib_nbextensions.nbextensions' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'jupyter_contrib_nbextensions.nbextensions.contrib_nbextensions_help_item' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.contrib_nbextensions_help_item' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'jupyter_contrib_nbextensions.nbextensions.contrib_nbextensions_help_item' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'jupyter_contrib_nbextensions.nbextensions.contrib_nbextensions_help_item' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'jupyter_contrib_nbextensions.nbextensions.css_selector' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.css_selector' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'jupyter_contrib_nbextensions.nbextensions.css_selector' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'jupyter_contrib_nbextensions.nbextensions.css_selector' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'jupyter_contrib_nbextensions.nbextensions.css_selector.css' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.css_selector.css' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'jupyter_contrib_nbextensions.nbextensions.css_selector.css' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'jupyter_contrib_nbextensions.nbextensions.css_selector.css' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
# ...
#       copying src/jupyter_contrib_core/notebook_compat/_compat/serverextensions.py -> build/lib/jupyter_contrib_core/notebook_compat/_compat
#       running egg_info
#       writing src/jupyter_contrib_core.egg-info/PKG-INFO
#       writing dependency_links to src/jupyter_contrib_core.egg-info/dependency_links.txt
#       writing entry points to src/jupyter_contrib_core.egg-info/entry_points.txt
#       writing requirements to src/jupyter_contrib_core.egg-info/requires.txt
#       writing top-level names to src/jupyter_contrib_core.egg-info/top_level.txt
#       reading manifest file 'src/jupyter_contrib_core.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no previously-included files found matching '.bumpversion.cfg'
#       warning: no previously-included files found matching '.travis.yml'
#       warning: no previously-included files found matching 'appveyor.yml'
#       warning: no previously-included files found matching 'codecov.yml'
#       no previously-included directories found matching 'conda.recipe'
#       warning: no previously-included files matching '*~' found anywhere in distribution
#       warning: no previously-included files matching '__pycache__' found anywhere in distribution
#       warning: no previously-included files matching '*.py[cod]' found anywhere in distribution
#       warning: no previously-included files matching '.git' found anywhere in distribution
#       warning: no previously-included files matching '.ipynb_checkpoints' found anywhere in distribution
#       adding license file 'LICENSE.txt'
#       writing manifest file 'src/jupyter_contrib_core.egg-info/SOURCES.txt'
#       warning: build_py: byte-compiling is disabled, skipping.
#
#       /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       installing to build/bdist.linux-x86_64/wheel
#       running install
#       running install_lib
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-jfnqhz95/jupyter-contrib-core_052b5b46150441e681ace0d0ca68a9b2/setup.py", line 81, in <module>
#           main()
#         File "/tmp/pip-install-jfnqhz95/jupyter-contrib-core_052b5b46150441e681ace0d0ca68a9b2/setup.py", line 15, in main
#           setup(
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/__init__.py", line 108, in setup
#           return distutils.core.setup(**attrs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#                  ^^^^^^^^^^^^^^^^^^
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/dist.py", line 1213, in run_command
#           super().run_command(command)
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/wheel/bdist_wheel.py", line 360, in run
#           self.run_command("install")
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/dist.py", line 1213, in run_command
#           super().run_command(command)
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/command/install.py", line 68, in run
#           return orig.install.run(self)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/command/install.py", line 709, in run
#           self.run_command(cmd_name)
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/dist.py", line 1213, in run_command
#           super().run_command(command)
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 987, in run_command
#           cmd_obj.ensure_finalized()
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 111, in ensure_finalized
#           self.finalize_options()
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/command/install_lib.py", line 17, in finalize_options
#           self.set_undefined_options('install',('install_layout','install_layout'))
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 296, in set_undefined_options
#           setattr(self, dst_option, getattr(src_cmd_obj, src_option))
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 107, in __getattr__
#           raise AttributeError(attr)
#       AttributeError: install_layout. Did you mean: 'install_platlib'?
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for jupyter_contrib_core
#   Running setup.py clean for jupyter_contrib_core
# Failed to build jupyter_contrib_nbextensions jupyter_contrib_core
# Installing collected packages: jupyter_contrib_core, jupyter_nbextensions_configurator, jupyter_contrib_nbextensions
#   Running setup.py install for jupyter_contrib_core ... error
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for jupyter_contrib_core did not run successfully.
#   │ exit code: 1
#   ╰─> [88 lines of output]
#       /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/config/setupcfg.py:515: SetuptoolsDeprecationWarning: The license_file parameter is deprecated, use license_files instead.
#         warnings.warn(msg, warning_class)
#       running install
#       /home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running build_py
#       creating build
#       creating build/lib
#       creating build/lib/jupyter_contrib_core
#       copying src/jupyter_contrib_core/__init__.py -> build/lib/jupyter_contrib_core
#       copying src/jupyter_contrib_core/application.py -> build/lib/jupyter_contrib_core
#       creating build/lib/jupyter_contrib_core/testing_utils
#       copying src/jupyter_contrib_core/testing_utils/__init__.py -> build/lib/jupyter_contrib_core/testing_utils
#       copying src/jupyter_contrib_core/testing_utils/jupyter_env.py -> build/lib/jupyter_contrib_core/testing_utils
#       creating build/lib/jupyter_contrib_core/notebook_compat
#       copying src/jupyter_contrib_core/notebook_compat/nbextensions.py -> build/lib/jupyter_contrib_core/notebook_compat
#       copying src/jupyter_contrib_core/notebook_compat/__init__.py -> build/lib/jupyter_contrib_core/notebook_compat
#       copying src/jupyter_contrib_core/notebook_compat/serverextensions.py -> build/lib/jupyter_contrib_core/notebook_compat
#       creating build/lib/jupyter_contrib_core/notebook_compat/_compat
#       copying src/jupyter_contrib_core/notebook_compat/_compat/nbextensions.py -> build/lib/jupyter_contrib_core/notebook_compat/_compat
#       copying src/jupyter_contrib_core/notebook_compat/_compat/__init__.py -> build/lib/jupyter_contrib_core/notebook_compat/_compat
#       copying src/jupyter_contrib_core/notebook_compat/_compat/serverextensions.py -> build/lib/jupyter_contrib_core/notebook_compat/_compat
#       running egg_info
#       writing src/jupyter_contrib_core.egg-info/PKG-INFO
#       writing dependency_links to src/jupyter_contrib_core.egg-info/dependency_links.txt
#       writing entry points to src/jupyter_contrib_core.egg-info/entry_points.txt
#       writing requirements to src/jupyter_contrib_core.egg-info/requires.txt
#       writing top-level names to src/jupyter_contrib_core.egg-info/top_level.txt
#       reading manifest file 'src/jupyter_contrib_core.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no previously-included files found matching '.bumpversion.cfg'
#       warning: no previously-included files found matching '.travis.yml'
#       warning: no previously-included files found matching 'appveyor.yml'
#       warning: no previously-included files found matching 'codecov.yml'
#       no previously-included directories found matching 'conda.recipe'
#       warning: no previously-included files matching '*~' found anywhere in distribution
#       warning: no previously-included files matching '__pycache__' found anywhere in distribution
#       warning: no previously-included files matching '*.py[cod]' found anywhere in distribution
#       warning: no previously-included files matching '.git' found anywhere in distribution
#       warning: no previously-included files matching '.ipynb_checkpoints' found anywhere in distribution
#       adding license file 'LICENSE.txt'
#       writing manifest file 'src/jupyter_contrib_core.egg-info/SOURCES.txt'
#       warning: build_py: byte-compiling is disabled, skipping.
#
#       running install_lib
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-jfnqhz95/jupyter-contrib-core_052b5b46150441e681ace0d0ca68a9b2/setup.py", line 81, in <module>
#           main()
#         File "/tmp/pip-install-jfnqhz95/jupyter-contrib-core_052b5b46150441e681ace0d0ca68a9b2/setup.py", line 15, in main
#           setup(
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/__init__.py", line 108, in setup
#           return distutils.core.setup(**attrs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#                  ^^^^^^^^^^^^^^^^^^
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/dist.py", line 1213, in run_command
#           super().run_command(command)
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/command/install.py", line 68, in run
#           return orig.install.run(self)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/command/install.py", line 709, in run
#           self.run_command(cmd_name)
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/dist.py", line 1213, in run_command
#           super().run_command(command)
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 987, in run_command
#           cmd_obj.ensure_finalized()
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 111, in ensure_finalized
#           self.finalize_options()
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/command/install_lib.py", line 17, in finalize_options
#           self.set_undefined_options('install',('install_layout','install_layout'))
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 296, in set_undefined_options
#           setattr(self, dst_option, getattr(src_cmd_obj, src_option))
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/home/hansofex/.local/share/virtualenvs/submission-python-data-analysis-project-BhsVTfYn/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 107, in __getattr__
#           raise AttributeError(attr)
#       AttributeError: install_layout. Did you mean: 'install_platlib'?
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> jupyter_contrib_core
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %% [markdown]
# ### Pertanyaan 2:

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# - conclution pertanyaan 2
